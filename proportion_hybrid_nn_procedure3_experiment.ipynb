# %% [markdown]
# # Proportion-based hybrid nearest neighbors with all cross-validations using classical k-nearest neighbors, plot generation

# %% [markdown]
# ## Imports

# %%
# import cuml
# cuml.accel.install()
# %load_ext cuml.accel
# %load_ext autoreload
# %load_ext rpy2.ipython
# %autoreload 2
# %reload_ext autoreload
import numpy as np
import multiprocessing as mp
import matplotlib.pyplot as plt
import pandas as pd
from pandas.io.parsers import read_csv
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from hybrids import max_pareto_front, hyb_KNeighborsClassifier
import pylab
# Swap KNeighborsClassifier if no gpu
from cuml.neighbors import KNeighborsClassifier
# from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import auc
import matplotlib.pyplot as plt
# %matplotlib inline
pylab.rcParams['figure.figsize'] = (5, 5)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# ## Data reading

# %%
blackbox = 'rf'  # Random forest
# blackbox = 'ab'  # AdaBoosted decision trees
# blackbox = 'xg'  # XGboost (gbtree)

# %%
path = './datasets/census/'; name = 'census'

# path = './datasets/coupon/'; name = 'coupon'

# path = './datasets/stop&frisk/'; name = 'stop-and-frisk'

# %%
normalize = True

# read data
Xtrain = read_csv(path + 'train.csv',header = 0, sep = ',')
Xtest = read_csv(path + 'test.csv',header = 0, sep = ',')
bbm = read_csv(path + blackbox + '_ybtrain.csv',header = 0,sep = ',')
Ybtrain = np.array(bbm['Yb'])
bbm = read_csv(path + blackbox + '_ybtest.csv',header = 0,sep = ',')
Ybtest = np.array(bbm['Yb'])

ntrain = Xtrain.shape[0]
df = pd.concat([Xtrain, Xtest])
# Seperate Y (answers) from dataframe
Y = np.array(df['Y'])
df.drop(['Y'], axis = 1, inplace = True) 
numericals = [col for col in Xtrain.columns if Xtrain[col].dtype in [int, float] and (~Xtrain[col].isin([0, 1])).any()]

if normalize:
    # Normalize data
    df = df.astype({col: float for col in numericals})
    mean = Xtrain.loc[:, numericals].mean(axis=0)
    std = Xtrain.loc[:, numericals].std(axis=0) + 1e-8
    df.loc[:, numericals] = (df.loc[:, numericals] - mean) / std


ntrain = Xtrain.shape[0]
Ytrain = Y[:ntrain]
Ytest = Y[ntrain:]
Xtrain = df[:ntrain].to_numpy()
Xtest = df[ntrain:].to_numpy()

# %% [markdown]
# ## Calculate probabilities for probabilistic KNN

# %% [markdown]
# Using greedy search to try finding best subset for all amount of features

# %%
feature_len = Xtrain.shape[1]
# False for backward feature selection
forward = True
# maximum k for k selection via cross-validation
max_k = 20
do_cv = True

feature_len = Xtrain.shape[1]
grid = KNeighborsClassifier(n_neighbors=11, n_jobs=1)
        
# perform sequential feature search (greedy search)
SFS1 = SFS(
    grid,
    k_features=(1, feature_len),
    forward=forward,
    floating=False,
    n_jobs=1,
    verbose=1,
    cv=2
)

SFS1.fit(Xtrain, Ytrain)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:    1.3s finished
# Features: 1/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 107 out of 107 | elapsed:    1.8s finished
# Features: 2/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=1)]: Done 106 out of 106 | elapsed:    1.9s finished
# Features: 3/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 105 out of 105 | elapsed:    1.4s finished
# Features: 4/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done 104 out of 104 | elapsed:    1.4s finished
# Features: 5/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 103 out of 103 | elapsed:    1.4s finished
# Features: 6/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 102 out of 102 | elapsed:    1.4s finished
# Features: 7/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 101 out of 101 | elapsed:    1.4s finished
# Features: 8/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.5s finished
# Features: 9/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:    1.4s finished
# Features: 10/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  98 out of  98 | elapsed:    1.5s finished
# Features: 11/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  97 out of  97 | elapsed:    1.4s finished
# Features: 12/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  96 out of  96 | elapsed:    1.5s finished
# Features: 13/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done  95 out of  95 | elapsed:    1.5s finished
# Features: 14/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done  94 out of  94 | elapsed:    1.5s finished
# Features: 15/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done  93 out of  93 | elapsed:    1.5s finished
# Features: 16/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=1)]: Done  92 out of  92 | elapsed:    1.8s finished
# Features: 17/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  91 out of  91 | elapsed:    1.8s finished
# Features: 18/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:    1.8s finished
# Features: 19/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  89 out of  89 | elapsed:    1.8s finished
# Features: 20/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  88 out of  88 | elapsed:    1.8s finished
# Features: 21/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  87 out of  87 | elapsed:    1.7s finished
# Features: 22/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  86 out of  86 | elapsed:    1.7s finished
# Features: 23/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  85 out of  85 | elapsed:    1.7s finished
# Features: 24/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  84 out of  84 | elapsed:    1.7s finished
# Features: 25/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  83 out of  83 | elapsed:    1.7s finished
# Features: 26/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  82 out of  82 | elapsed:    1.7s finished
# Features: 27/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  81 out of  81 | elapsed:    1.7s finished
# Features: 28/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:    1.7s finished
# Features: 29/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=1)]: Done  79 out of  79 | elapsed:    1.8s finished
# Features: 30/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=1)]: Done  78 out of  78 | elapsed:    1.7s finished
# Features: 31/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  77 out of  77 | elapsed:    1.7s finished
# Features: 32/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=1)]: Done  76 out of  76 | elapsed:    1.9s finished
# Features: 33/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=1)]: Done  75 out of  75 | elapsed:    1.9s finished
# Features: 34/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=1)]: Done  74 out of  74 | elapsed:    1.9s finished
# Features: 35/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  73 out of  73 | elapsed:    1.9s finished
# Features: 36/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:    1.9s finished
# Features: 37/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:    1.9s finished
# Features: 38/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:    2.0s finished
# Features: 39/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:    1.9s finished
# Features: 40/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:    1.9s finished
# Features: 41/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:    1.8s finished
# Features: 42/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:    1.8s finished
# Features: 43/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:    1.8s finished
# Features: 44/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    1.8s finished
# Features: 45/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    1.7s finished
# Features: 46/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed:    1.7s finished
# Features: 47/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed:    1.8s finished
# Features: 48/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    2.0s finished
# Features: 49/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed:    2.0s finished
# Features: 50/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed:    1.9s finished
# Features: 51/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed:    1.9s finished
# Features: 52/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:    1.9s finished
# Features: 53/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:    1.8s finished
# Features: 54/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:    1.8s finished
# Features: 55/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:    1.8s finished
# Features: 56/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:    1.8s finished
# Features: 57/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:    1.7s finished
# Features: 58/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    1.7s finished
# Features: 59/108[Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:    1.7s finished
# Features: 60/108[Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed:    1.7s finished
# Features: 61/108[Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed:    1.7s finished
# Features: 62/108[Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed:    1.7s finished
# Features: 63/108[Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    1.6s finished
# Features: 64/108[Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:    1.8s finished
# Features: 65/108[Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:    1.7s finished
# Features: 66/108[Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:    1.7s finished
# Features: 67/108[Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:    1.6s finished
# Features: 68/108[Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    1.6s finished
# Features: 69/108[Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:    1.6s finished
# Features: 70/108[Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:    1.5s finished
# Features: 71/108[Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:    1.6s finished
# Features: 72/108[Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:    1.5s finished
# Features: 73/108[Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:    1.5s finished
# Features: 74/108[Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:    1.5s finished
# Features: 75/108[Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:    1.5s finished
# Features: 76/108[Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:    1.4s finished
# Features: 77/108[Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:    1.4s finished
# Features: 78/108[Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    1.4s finished
# Features: 79/108[Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    1.3s finished
# Features: 80/108[Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    1.4s finished
# Features: 81/108[Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    1.3s finished
# Features: 82/108[Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    1.3s finished
# Features: 83/108[Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    1.3s finished
# Features: 84/108[Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    1.2s finished
# Features: 85/108[Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.2s finished
# Features: 86/108[Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    1.1s finished
# Features: 87/108[Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    1.0s finished
# Features: 88/108[Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    1.0s finished
# Features: 89/108[Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    1.0s finished
# Features: 90/108[Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.9s finished
# Features: 91/108[Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.9s finished
# Features: 92/108[Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.8s finished
# Features: 93/108[Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.8s finished
# Features: 94/108[Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.7s finished
# Features: 95/108[Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.7s finished
# Features: 96/108[Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.7s finished
# Features: 97/108[Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.6s finished
# Features: 98/108[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.6s finished
# Features: 99/108[Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.5s finished
# Features: 100/108[Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.5s finished
# Features: 101/108[Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.4s finished
# Features: 102/108[Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.3s finished
# Features: 103/108[Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
# Features: 104/108[Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s finished
# Features: 105/108[Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s finished
# Features: 106/108[Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s finished
# Features: 107/108[Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# Features: 108/108
# SequentialFeatureSelector(cv=2, estimator=KNeighborsClassifier(),
#                           k_features=(1, 108), scoring='accuracy', verbose=1)

# %%
results = []
test_num = len(Ytest)
if do_cv:
    param_grid = {'n_neighbors': range(5, max_k+1)}
    grid = GridSearchCV(KNeighborsClassifier(), param_grid, n_jobs=1, refit=True, verbose=0)
else:
    grid = KNeighborsClassifier(n_neighbors=max_k, n_jobs=1)

def fit_one(i):
    print(f"Features: {i+1}")
    res = []
    feature_subset = np.array(SFS1.subsets_[i+1]['feature_idx'])
    
    grid.fit(Xtrain[:, feature_subset], Ytrain)
    probs = grid.predict_proba(Xtest[:, feature_subset])
    if isinstance(probs, pd.DataFrame):
        prob = probs.iloc[:, 1].to_numpy()
    else:
        prob = np.asarray(probs)[:, 1]
    Yhat = (prob >= 0.5)
    for offload_thrs in np.append(np.linspace(0, 0.5, 20, True), 0.6):
        # probability too close to 0.5 will be defered to black-box yhat
        hyb_yhat = np.copy(Yhat)
        mask = np.abs(prob - 0.5) < offload_thrs
        covered_amount = test_num - np.sum(mask)
        hyb_yhat[mask] = Ybtest[mask]

        correct_amount = np.count_nonzero(hyb_yhat == Ytest)
        transparency = covered_amount / test_num
        accuracy = correct_amount / test_num
        res.append( {
            'offload_thrs': offload_thrs,
            'transparency': transparency,
            'accuracy': accuracy,
            'features_used': i+1,
            'k-nearest': grid.best_estimator_.n_neighbors if do_cv else grid.n_neighbors
        })
    return res

for features in range(feature_len):
    results.extend(fit_one(features))

# Save as csv
results_df = pd.DataFrame(results)
# results_df.to_csv(path + f"{name}_{blackbox}_hybkNN_proc3_{"le" if do_cv else "eq"}{max_k}{"fwgreedy" if forward else "bcgreedy"}_results.csv", index=False)
# Out:
# Features: 1
# Features: 2
# Features: 3
# Features: 4
# Features: 5
# Features: 6
# Features: 7
# Features: 8
# Features: 9
# Features: 10
# Features: 11
# Features: 12
# Features: 13
# Features: 14
# Features: 15
# Features: 16
# Features: 17
# Features: 18
# Features: 19
# Features: 20
# Features: 21
# Features: 22
# Features: 23
# Features: 24
# Features: 25
# Features: 26
# Features: 27
# Features: 28
# Features: 29
# Features: 30
# Features: 31
# Features: 32
# Features: 33
# Features: 34
# Features: 35
# Features: 36
# Features: 37
# Features: 38
# Features: 39
# Features: 40
# Features: 41
# Features: 42
# Features: 43
# Features: 44
# Features: 45
# Features: 46
# Features: 47
# Features: 48
# Features: 49
# Features: 50
# Features: 51
# Features: 52
# Features: 53
# Features: 54
# Features: 55
# Features: 56
# Features: 57
# Features: 58
# Features: 59
# Features: 60
# Features: 61
# Features: 62
# Features: 63
# Features: 64
# Features: 65
# Features: 66
# Features: 67
# Features: 68
# Features: 69
# Features: 70
# Features: 71
# Features: 72
# Features: 73
# Features: 74
# Features: 75
# Features: 76
# Features: 77
# Features: 78
# Features: 79
# Features: 80
# Features: 81
# Features: 82
# Features: 83
# Features: 84
# Features: 85
# Features: 86
# Features: 87
# Features: 88
# Features: 89
# Features: 90
# Features: 91
# Features: 92
# Features: 93
# Features: 94
# Features: 95
# Features: 96
# Features: 97
# Features: 98
# Features: 99
# Features: 100
# Features: 101
# Features: 102
# Features: 103
# Features: 104
# Features: 105
# Features: 106
# Features: 107
# Features: 108

# %% [markdown]
# ## Plot predictions

# %%
# Create the plot
plt.figure(figsize=(10, 8))

transparency_vals = [result['transparency'] for result in results]
accuracy_vals = [result['accuracy'] for result in results]
features_vals = [result['features_used'] for result in results]

scatter = plt.scatter(
    transparency_vals,
    accuracy_vals,
    c=features_vals,
    cmap='viridis_r',
    s=100,
    alpha=0.8,
    edgecolors='black',
    linewidths=0.3,
 )

cbar = plt.colorbar(scatter)
cbar.set_label('Amount used feature', fontsize=11)

plt.xlabel('Transparency', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title(f'Prediction scatter of {name}: {blackbox} hybrid k-nearest neighbors', fontsize=14)
plt.grid(True, alpha=0.3)
plt.xlim(-0.05, 1.05)
plt.tight_layout()
# plt.savefig(path + f"{name}_{blackbox}_hybkNN_proc3_{"le" if do_cv else "eq"}{max_k}{"fwgreedy" if forward else "bcgreedy"}_scatter.svg")
plt.show()

# %% [markdown]
# #### Pareto front with unlimited features

# %%
maxpf_df = max_pareto_front(results_df, "transparency", "accuracy")
yb_accuracy = (Ybtest == Ytest).mean()
# Create the plot
plt.figure(figsize=(10, 8))


axes = plt.gca()
plt.plot([0, maxpf_df.iloc[-1]["transparency"]], [yb_accuracy, maxpf_df.iloc[-1]["accuracy"]], color="black")
axes = maxpf_df.plot(x="transparency", y="accuracy", ax=axes, marker='s', markersize=20, markerfacecolor='white', markeredgecolor='blue', label="hybrid KNN")
plt.plot(0, yb_accuracy, 's', markersize=20, markerfacecolor='black', markeredgecolor='black')
for i, row in maxpf_df.iterrows():
    plt.text(row["transparency"], row["accuracy"], int(row["features_used"]), 
             ha='center', 
             va='center', 
             fontsize=12, 
             color='black', 
             )
plt.text(0, yb_accuracy, blackbox,
         ha='center', 
         va='center', 
         fontsize=12, 
         fontweight="bold",
         color="white")
plt.xlabel('Transparency', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title(f'Pareto of predictions of {name}: {blackbox} hybrid kNN', fontsize=14)
plt.grid(True, alpha=0.3)
plt.xlim(-0.05, 1.05)
plt.tight_layout()
# plt.savefig(path + f'{name}_{blackbox}_hybkNN_proc3_{"le" if do_cv else "eq"}{max_k}{"fwgreedy" if forward else "bcgreedy"}_pareto.svg')
plt.show()

# %% [markdown]
# #### Pareto front with dataframe filtered by amount of features used

# %%
le_feature = 2
maxpf_df = max_pareto_front(results_df[results_df["features_used"] <= le_feature], "transparency", "accuracy")
yb_accuracy = (Ybtest == Ytest).mean()
# Create the plot
plt.figure(figsize=(10, 8))


axes = plt.gca()
plt.plot([0, maxpf_df.iloc[-1]["transparency"]], [yb_accuracy, maxpf_df.iloc[-1]["accuracy"]], color="black")
axes = maxpf_df.plot(x="transparency", y="accuracy", ax=axes, marker='s', markersize=20, markerfacecolor='white', markeredgecolor='blue', label="hybrid KNN")
plt.plot(0, yb_accuracy, 's', markersize=20, markerfacecolor='black', markeredgecolor='black')
for i, row in maxpf_df.iterrows():
    plt.text(row["transparency"], row["accuracy"], int(row["features_used"]), 
             ha='center', 
             va='center', 
             fontsize=12, 
             color='black', 
             )
plt.text(0, yb_accuracy, blackbox,
         ha='center', 
         va='center', 
         fontsize=12, 
         fontweight="bold",
         color="white")
plt.xlabel('Transparency', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.title(f'Pareto of predictions of {name}: {blackbox} hybrid NN with <={le_feature} features', fontsize=14)
plt.grid(True, alpha=0.3)
plt.xlim(-0.05, 1.05)
plt.tight_layout()
# plt.savefig(path + f'{name}_{blackbox}_hybkNN_proc3_{"le" if do_cv else "eq"}{max_k}{"fwgreedy" if forward else "bcgreedy"}_pareto_featurefilteredby{le_feature}.svg')
plt.show()

# %% [markdown]
# ## Colerful AUTAC (area under the accuracy-transparency trade-off curve) bar

# %%
def get_autacs(th):
    pareto_df = max_pareto_front(
        (results_df[results_df["features_used"] <= th]) if th != None else results_df, "transparency", "accuracy"
    ).sort_values("transparency", ascending=False, ignore_index=True)
    pareto_df.loc[len(pareto_df)] = {
        "offload_thrs": 0,
        "transparency": 0,
        "accuracy": pareto_df["accuracy"].iloc[-1],
        "features_used": pareto_df["features_used"].iloc[-1],
    }
    return auc(pareto_df["transparency"], pareto_df["accuracy"])

ax = plt.gca()


feature_filter_list = [2] + list(range(10, 101, 10)) + [None]
autacs = [get_autacs(th) for th in feature_filter_list]
labels = [f"feature$\\leq{th}$" if th is not None else "No restriction" for th in feature_filter_list]
colors = [f"C{i}" for i in range(10)] + ["teal", "black"]

au_max = max(autacs)
au_min = min(autacs)
margin = (au_max - au_min) * 0.05
range_min = au_min - margin
range_max = au_max + margin

for idx, autac in enumerate(autacs):
    print(f"AUTAC with {labels[idx]}:",autac)
    ax.bar(
        [f"No black-box, {"fw" if forward else "bw"}"], 
        autac, label=labels[idx], 
        color=colors[idx], 
        zorder=-idx
        )
ax.set_ylim(range_min, range_max)
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# AUTAC with feature$\leq2$: 0.8464493098510327
# AUTAC with feature$\leq10$: 0.8617835942429016
# AUTAC with feature$\leq20$: 0.8617843845973003
# AUTAC with feature$\leq30$: 0.8617808044239142
# AUTAC with feature$\leq40$: 0.8617808044239142
# AUTAC with feature$\leq50$: 0.8617808195142131
# AUTAC with feature$\leq60$: 0.8617808195142131
# AUTAC with feature$\leq70$: 0.8617808195142131
# AUTAC with feature$\leq80$: 0.8617808195142131
# AUTAC with feature$\leq90$: 0.8617808195142131
# AUTAC with feature$\leq100$: 0.8617808195142131
# AUTAC with No restriction: 0.8617808195142131
